# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("exams.csv")
df.head()
# Out:
#    gênero raça/etnia nível de escolaridade parental          almoço  \
# 0   homem    grupo A                   ensino médio          padrão
# 1  mulher    grupo D             algum ensino médio  livre/reduzido
# 2   homem    grupo E               alguma faculdade  livre/reduzido
# 3   homem    grupo B                   ensino médio          padrão
# 4   homem    grupo E              grau de associado          padrão
#
#   curso preparatório para teste  pontuação de matemática  \
# 0                     concluído                       67
# 1                        nenhum                       40
# 2                        nenhum                       59
# 3                        nenhum                       77
# 4                     concluído                       78
#
#    pontuação de leitura  pontuação de escrita
# 0                    67                    63
# 1                    59                    55
# 2                    60                    50
# ...

# %%
df.describe()
# Out:
#        pontuação de matemática  pontuação de leitura  pontuação de escrita
# count              1000.000000           1000.000000           1000.000000
# mean                 66.396000             69.002000             67.738000
# std                  15.402871             14.737272             15.600985
# min                  13.000000             27.000000             23.000000
# 25%                  56.000000             60.000000             58.000000
# 50%                  66.500000             70.000000             68.000000
# 75%                  77.000000             79.000000             79.000000
# max                 100.000000            100.000000            100.000000

# %%
df.columns
columns = df.columns

# %%
def bar_plot(variable):

    var = df[variable]
    
    varValue = var.value_counts()
    

    plt.figure(figsize =(5,5))
    plt.bar(varValue.index, varValue)
    plt.xticks(varValue.index, varValue.index.values,rotation=45)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable,varValue))

# %%
for c in columns:
    
    bar_plot(c)
# Out:
# gênero:
#  homem     517
# mulher    483
# Name: gênero, dtype: int64
# raça/etnia:
#  grupo C    323
# grupo D    262
# grupo B    205
# grupo E    131
# grupo A     79
# Name: raça/etnia, dtype: int64
# nível de escolaridade parental:
#  alguma faculdade       222
# grau de associado      203
# ensino médio           202
# algum ensino médio     191
# diploma de bacharel    112
# mestrado                70
# Name: nível de escolaridade parental, dtype: int64
# almoço:
#  padrão            652
# livre/reduzido    348
# Name: almoço, dtype: int64
# curso preparatório para teste:
#  nenhum       665
# concluído    335
# Name: curso preparatório para teste, dtype: int64
# pontuação de matemática:
#  63    34
# 71    30
# 77    30
# 74    28
# 57    27
#       ..
# 26     2
# 23     1
# 29     1
# 34     1
# 25     1
# Name: pontuação de matemática, Length: 77, dtype: int64
# pontuação de leitura:
#  71    36
# 63    34
# 64    32
# 78    31
# 73    31
#       ..
# 33     2
# 98     2
# ...

# %%
sns.barplot(data=df, x="pontuação de matemática", y="nível de escolaridade parental")
plt.show()

# %%
sns.color_palette("bright")
sns.barplot(data=df, x="pontuação de matemática", y="curso preparatório para teste")
plt.show()

# %%
sns.barplot(data=df, x="pontuação de leitura", y="curso preparatório para teste")
plt.show()

# %%
sns.barplot(data=df, x="pontuação de escrita", y="curso preparatório para teste")
plt.show()

# %%
sns.barplot(data=df, x="pontuação de matemática", y="almoço")
plt.show()
